# %% [markdown]
# # Libraries

# %%
# !pip install wget
import numpy as np
import pandas as pd
import wget
from zipfile import ZipFile
from google.colab.data_table import DataTable
import plotly.graph_objects as go

# %% [markdown]
# # Variables

# %%
# I opened the site and saw that all companys are clustered together on zip files annually
url_base = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/'

# %%
arquivos_zip = []
# made a loop to get all zip files years available
for ano in range(2010,2022):
  arquivos_zip.append(f'dfp_cia_aberta_{ano}.zip')

arquivos_zip
# Out:
# ['dfp_cia_aberta_2010.zip',
#  'dfp_cia_aberta_2011.zip',
#  'dfp_cia_aberta_2012.zip',
#  'dfp_cia_aberta_2013.zip',
#  'dfp_cia_aberta_2014.zip',
#  'dfp_cia_aberta_2015.zip',
#  'dfp_cia_aberta_2016.zip',
#  'dfp_cia_aberta_2017.zip',
#  'dfp_cia_aberta_2018.zip',
#  'dfp_cia_aberta_2019.zip',
#  'dfp_cia_aberta_2020.zip',
#  'dfp_cia_aberta_2021.zip']

# %%
#downloaded the zip file with wget
for arq in arquivos_zip:
  wget.download(url_base+arq)

# %%
for arq in arquivos_zip:
  ZipFile(arq, 'r').extractall('CVM')

# %%
# !mkdir DADOS_DFP

# %%
#performing loop through the zip files, building .csv and compiling by type.
nomes = ['BPA_con', 'BPA_ind','BPP_con','BPP_ind','DFC_MD_con','DFC_MD_ind','DFC_MI_con','DFC_MI_ind','DMPL_con','DMPL_ind','DRE_con','DRE_ind','DVA_con','DVA_ind']
for nome in nomes:
  arquivo = pd.DataFrame()
  for ano in range(2010,2022):
    arquivo = pd.concat([arquivo,pd.read_csv(f'/content/CVM/dfp_cia_aberta_{nome}_{ano}.csv', sep=';', decimal=',', encoding='ISO-8859-1')])
  arquivo.to_csv(f'DADOS_DFP/dfp_cia_aberta_{nome}_2010-2021.csv', index = False)

# %%
dre = pd.read_csv('/content/DADOS_DFP/dfp_cia_aberta_DRE_ind_2010-2021.csv')

# %%
dre = dre[dre['ORDEM_EXERC'] == "ÚLTIMO"]

# %%
dre.head(3)
# Out:
#              CNPJ_CIA    DT_REFER  VERSAO        DENOM_CIA  CD_CVM  \
# 1  00.000.000/0001-91  2010-12-31       3  BCO BRASIL S.A.    1023
# 3  00.000.000/0001-91  2010-12-31       3  BCO BRASIL S.A.    1023
# 5  00.000.000/0001-91  2010-12-31       3  BCO BRASIL S.A.    1023
#
#                                    GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 1  DF Individual - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 3  DF Individual - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 5  DF Individual - Demonstração do Resultado  REAL          MIL      ÚLTIMO
#
#   DT_INI_EXERC DT_FIM_EXERC CD_CONTA                              DS_CONTA  \
# 1   2010-01-01   2010-12-31     3.01  Receitas da Intermediação Financeira
# 3   2010-01-01   2010-12-31  3.01.01                  Operações de Crédito
# 5   2010-01-01   2010-12-31  3.01.02   Operações de Arrendamento Mercantil
#
#      VL_CONTA ST_CONTA_FIXA
# 1  72173904.0             S
# 3  47391099.0             N
# 5     40372.0             N

# %%
# build a datatable with CVM code and enterprise name for easy access and recognition.
empresas = dre[['DENOM_CIA','CD_CVM']].drop_duplicates().set_index('CD_CVM')
DataTable(empresas)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DENOM_CIA</th>
#     </tr>
#     <tr>
#       <th>CD_CVM</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1023</th>
#       <td>BCO BRASIL S.A.</td>
#     </tr>
#     <tr>
#       <th>14206</th>
#       <td>BRB BCO DE BRASILIA S.A.</td>
#     </tr>
#     <tr>
#       <th>2437</th>
#       <td>CENTRAIS ELET BRAS S.A. - ELETROBRAS</td>
#     </tr>
#     <tr>
#       <th>14451</th>
#       <td>CIA ENERGETICA DE BRASILIA</td>
#     </tr>
#     <tr>
#       <th>14540</th>
#       <td>VBC ENERGIA SA</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>26239</th>
#       <td>TRAVESSIA SECURITIZADORA DE CRÉDITOS FINANCEIR...</td>
#     </tr>
#     <tr>
#       <th>26441</th>
#       <td>OMEGA ENERGIA S.A.</td>
#     </tr>
#     <tr>
#       <th>26492</th>
#       <td>TRUE SECURITIZADORA DE CREDITOS FINANCEIROS IV...</td>
#     </tr>
#     <tr>
#       <th>26549</th>
#       <td>CLARANET TECHNOLOGY S.A.</td>
#     </tr>
#     <tr>
#       <th>26395</th>
#       <td>ALMEIDA JUNIOR SHOPPING CENTERS S.A.</td>
#     </tr>
#   </tbody>
# </table>
# <p>1090 rows × 1 columns</p>
# </div>

# %%
empresa = dre[dre['CD_CVM'] == 20257]

# %%
empresa.head()
# Out:
#                  CNPJ_CIA    DT_REFER  VERSAO  \
# 15696  07.859.971/0001-30  2010-12-31       2
# 15698  07.859.971/0001-30  2010-12-31       2
# 15700  07.859.971/0001-30  2010-12-31       2
# 15702  07.859.971/0001-30  2010-12-31       2
# 15704  07.859.971/0001-30  2010-12-31       2
#
#                                            DENOM_CIA  CD_CVM  \
# 15696  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 15698  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 15700  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 15702  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 15704  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
#
#                                        GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 15696  DF Individual - Demonstração do Resultado  REAL          MIL
# 15698  DF Individual - Demonstração do Resultado  REAL          MIL
# 15700  DF Individual - Demonstração do Resultado  REAL          MIL
# 15702  DF Individual - Demonstração do Resultado  REAL          MIL
# 15704  DF Individual - Demonstração do Resultado  REAL          MIL
#
#       ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC CD_CONTA  \
# 15696      ÚLTIMO   2010-01-01   2010-12-31     3.01
# 15698      ÚLTIMO   2010-01-01   2010-12-31     3.02
# 15700      ÚLTIMO   2010-01-01   2010-12-31  3.02.01
# 15702      ÚLTIMO   2010-01-01   2010-12-31  3.02.02
# 15704      ÚLTIMO   2010-01-01   2010-12-31  3.02.03
#
#                                      DS_CONTA  VL_CONTA ST_CONTA_FIXA
# 15696  Receita de Venda de Bens e/ou Serviços       0.0             S
# 15698   Custo dos Bens e/ou Serviços Vendidos       0.0             S
# 15700               Pessoal e Administradores       0.0             N
# 15702                                Material       0.0             N
# 15704                   Serviços de Terceiros       0.0             N

# %%
#those are the acounts on income statement
DataTable(empresa[['CD_CONTA', 'DS_CONTA']].drop_duplicates().set_index('CD_CONTA'))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DS_CONTA</th>
#     </tr>
#     <tr>
#       <th>CD_CONTA</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3.01</th>
#       <td>Receita de Venda de Bens e/ou Serviços</td>
#     </tr>
#     <tr>
#       <th>3.02</th>
#       <td>Custo dos Bens e/ou Serviços Vendidos</td>
#     </tr>
#     <tr>
#       <th>3.02.01</th>
#       <td>Pessoal e Administradores</td>
#     </tr>
#     <tr>
#       <th>3.02.02</th>
#       <td>Material</td>
#     </tr>
#     <tr>
#       <th>3.02.03</th>
#       <td>Serviços de Terceiros</td>
#     </tr>
#     <tr>
#       <th>3.02.04</th>
#       <td>Depreciação e Amortização</td>
#     </tr>
#     <tr>
#       <th>3.02.05</th>
#       <td>Outros Custos Operacionais</td>
#     </tr>
#     <tr>
#       <th>3.03</th>
#       <td>Resultado Bruto</td>
#     </tr>
#     <tr>
#       <th>3.04</th>
#       <td>Despesas/Receitas Operacionais</td>
#     </tr>
#     <tr>
#       <th>3.04.01</th>
#       <td>Despesas com Vendas</td>
#     </tr>
#     <tr>
#       <th>3.04.02</th>
#       <td>Despesas Gerais e Administrativas</td>
#     </tr>
#     <tr>
#       <th>3.04.03</th>
#       <td>Perdas pela Não Recuperabilidade de Ativos</td>
#     </tr>
#     <tr>
#       <th>3.04.04</th>
#       <td>Outras Receitas Operacionais</td>
#     </tr>
#     <tr>
#       <th>3.04.05</th>
#       <td>Outras Despesas Operacionais</td>
#     </tr>
#     <tr>
#       <th>3.04.05.01</th>
#       <td>Serviços de Terceiros</td>
#     </tr>
#     <tr>
#       <th>3.04.05.02</th>
#       <td>Depreciação e Amortização</td>
#     </tr>
#     <tr>
#       <th>3.04.05.03</th>
#       <td>Outras Despesas operacionais</td>
#     </tr>
#     <tr>
#       <th>3.04.06</th>
#       <td>Resultado de Equivalência Patrimonial</td>
#     </tr>
#     <tr>
#       <th>3.05</th>
#       <td>Resultado Antes do Resultado Financeiro e dos ...</td>
#     </tr>
#     <tr>
#       <th>3.06</th>
#       <td>Resultado Financeiro</td>
#     </tr>
#     <tr>
#       <th>3.06.01</th>
#       <td>Receitas Financeiras</td>
#     </tr>
#     <tr>
#       <th>3.06.01.01</th>
#       <td>Renda de Aplicação Financeira</td>
#     </tr>
#     <tr>
#       <th>3.06.02</th>
#       <td>Despesas Financeiras</td>
#     </tr>
#     <tr>
#       <th>3.06.02.01</th>
#       <td>Encargos de dívidas</td>
#     </tr>
#     <tr>
#       <th>3.06.02.02</th>
#       <td>Variações Monetárias</td>
#     </tr>
#     <tr>
#       <th>3.06.02.03</th>
#       <td>Outras Despesas Financeiras</td>
#     </tr>
#     <tr>
#       <th>3.07</th>
#       <td>Resultado Antes dos Tributos sobre o Lucro</td>
#     </tr>
#     <tr>
#       <th>3.08</th>
#       <td>Imposto de Renda e Contribuição Social sobre o...</td>
#     </tr>
#     <tr>
#       <th>3.08.01</th>
#       <td>Corrente</td>
#     </tr>
#     <tr>
#       <th>3.08.02</th>
#       <td>Diferido</td>
#     </tr>
#     <tr>
#       <th>3.09</th>
#       <td>Resultado Líquido das Operações Continuadas</td>
#     </tr>
#     <tr>
#       <th>3.10</th>
#       <td>Resultado Líquido de Operações Descontinuadas</td>
#     </tr>
#     <tr>
#       <th>3.10.01</th>
#       <td>Lucro/Prejuízo Líquido das Operações Descontin...</td>
#     </tr>
#     <tr>
#       <th>3.10.02</th>
#       <td>Ganhos/Perdas Líquidas sobre Ativos de Operaçõ...</td>
#     </tr>
#     <tr>
#       <th>3.11</th>
#       <td>Lucro/Prejuízo do Período</td>
#     </tr>
#     <tr>
#       <th>3.99</th>
#       <td>Lucro por Ação - (Reais / Ação)</td>
#     </tr>
#     <tr>
#       <th>3.99.01</th>
#       <td>Lucro Básico por Ação</td>
#     </tr>
#     <tr>
#       <th>3.99.01.01</th>
#       <td>ON</td>
#     </tr>
#     <tr>
#       <th>3.99.01.02</th>
#       <td>PN</td>
#     </tr>
#     <tr>
#       <th>3.99.02</th>
#       <td>Lucro Diluído por Ação</td>
#     </tr>
#     <tr>
#       <th>3.99.02.01</th>
#       <td>ON</td>
#     </tr>
#     <tr>
#       <th>3.99.02.02</th>
#       <td>PN</td>
#     </tr>
#     <tr>
#       <th>3.04.02.01</th>
#       <td>Pessoal e Administradores</td>
#     </tr>
#     <tr>
#       <th>3.04.02.02</th>
#       <td>Serviços de Terceiros</td>
#     </tr>
#     <tr>
#       <th>3.04.02.03</th>
#       <td>Depreciação e Amortização</td>
#     </tr>
#     <tr>
#       <th>3.04.02.04</th>
#       <td>Outras Despesas Gerais e Administrativas, líqu...</td>
#     </tr>
#     <tr>
#       <th>3.04.04.01</th>
#       <td>Ganho na Remuneração na Aquisição do Controle ...</td>
#     </tr>
#     <tr>
#       <th>3.02.01</th>
#       <td>Pessoal</td>
#     </tr>
#     <tr>
#       <th>3.01.01</th>
#       <td>Receita de Venda de Bens e/ou Serviços</td>
#     </tr>
#     <tr>
#       <th>3.04.02.04</th>
#       <td>Outras Despesas Gerais e Administrativas</td>
#     </tr>
#     <tr>
#       <th>3.04.06.01</th>
#       <td>Resultado de Equivalência Patrimonial</td>
#     </tr>
#     <tr>
#       <th>3.04.02.03</th>
#       <td>Serviços de Terceiros</td>
#     </tr>
#     <tr>
#       <th>3.04.02.04</th>
#       <td>Depreciação e Amortização</td>
#     </tr>
#     <tr>
#       <th>3.04.02.05</th>
#       <td>Outras Despesas Gerais e Administrativas</td>
#     </tr>
#     <tr>
#       <th>3.01.01</th>
#       <td>Receita de infra, Correção monet, operação e m...</td>
#     </tr>
#     <tr>
#       <th>3.01.02</th>
#       <td>Remuneração dos ativos da concessão</td>
#     </tr>
#     <tr>
#       <th>3.04.02.02</th>
#       <td>Serviços de terceiros</td>
#     </tr>
#     <tr>
#       <th>3.04.06.01</th>
#       <td>Resultado de equivalência patrimonial</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
conta = empresa[empresa['CD_CONTA'] == '3.99.02.01']
conta.head()
# Out:
#                   CNPJ_CIA    DT_REFER  VERSAO  \
# 15776   07.859.971/0001-30  2010-12-31       2
# 56176   07.859.971/0001-30  2011-12-31       4
# 98314   07.859.971/0001-30  2012-12-31       1
# 140131  07.859.971/0001-30  2013-12-31       1
# 181379  07.859.971/0001-30  2014-12-31       1
#
#                                             DENOM_CIA  CD_CVM  \
# 15776   TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 56176   TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 98314   TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 140131  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 181379  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
#
#                                         GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 15776   DF Individual - Demonstração do Resultado  REAL          MIL
# 56176   DF Individual - Demonstração do Resultado  REAL          MIL
# 98314   DF Individual - Demonstração do Resultado  REAL          MIL
# 140131  DF Individual - Demonstração do Resultado  REAL          MIL
# 181379  DF Individual - Demonstração do Resultado  REAL          MIL
#
#        ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC    CD_CONTA DS_CONTA  VL_CONTA  \
# 15776       ÚLTIMO   2010-01-01   2010-12-31  3.99.02.01       ON   1.62700
# 56176       ÚLTIMO   2011-01-01   2011-12-31  3.99.02.01       ON   1.88010
# 98314       ÚLTIMO   2012-01-01   2012-12-31  3.99.02.01       ON   0.65628
# 140131      ÚLTIMO   2013-01-01   2013-12-31  3.99.02.01       ON   0.86391
# 181379      ÚLTIMO   2014-01-01   2014-12-31  3.99.02.01       ON   0.87552
#
#        ST_CONTA_FIXA
# 15776              N
# 56176              N
# 98314              N
# 140131             N
# 181379             N

# %%
conta.index = pd.to_datetime(conta['DT_REFER'])
conta.head()
# Out:
#                       CNPJ_CIA    DT_REFER  VERSAO  \
# DT_REFER
# 2010-12-31  07.859.971/0001-30  2010-12-31       2
# 2011-12-31  07.859.971/0001-30  2011-12-31       4
# 2012-12-31  07.859.971/0001-30  2012-12-31       1
# 2013-12-31  07.859.971/0001-30  2013-12-31       1
# 2014-12-31  07.859.971/0001-30  2014-12-31       1
#
#                                                 DENOM_CIA  CD_CVM  \
# DT_REFER
# 2010-12-31  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 2011-12-31  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 2012-12-31  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 2013-12-31  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
# 2014-12-31  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.   20257
#
#                                             GRUPO_DFP MOEDA ESCALA_MOEDA  \
# DT_REFER
# 2010-12-31  DF Individual - Demonstração do Resultado  REAL          MIL
# 2011-12-31  DF Individual - Demonstração do Resultado  REAL          MIL
# 2012-12-31  DF Individual - Demonstração do Resultado  REAL          MIL
# 2013-12-31  DF Individual - Demonstração do Resultado  REAL          MIL
# 2014-12-31  DF Individual - Demonstração do Resultado  REAL          MIL
#
#            ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC    CD_CONTA DS_CONTA  \
# DT_REFER
# 2010-12-31      ÚLTIMO   2010-01-01   2010-12-31  3.99.02.01       ON
# 2011-12-31      ÚLTIMO   2011-01-01   2011-12-31  3.99.02.01       ON
# 2012-12-31      ÚLTIMO   2012-01-01   2012-12-31  3.99.02.01       ON
# 2013-12-31      ÚLTIMO   2013-01-01   2013-12-31  3.99.02.01       ON
# 2014-12-31      ÚLTIMO   2014-01-01   2014-12-31  3.99.02.01       ON
#
#             VL_CONTA ST_CONTA_FIXA
# DT_REFER
# 2010-12-31   1.62700             N
# 2011-12-31   1.88010             N
# 2012-12-31   0.65628             N
# 2013-12-31   0.86391             N
# 2014-12-31   0.87552             N

# %% [markdown]
# ***BUILDING P/E RATIO***

# %%
# !pip install yfinance
import yfinance as yf

# %%
prices = yf.download('TAEE11.SA', start='2012-01-01')[['Adj Close','Close']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
prices
# Out:
#             Adj Close      Close
# Date
# 2012-01-02   4.719447  12.400000
# 2012-01-03   4.782880  12.566666
# 2012-01-04   4.782880  12.566666
# 2012-01-05   4.782880  12.566666
# 2012-01-06   4.782880  12.566666
# ...               ...        ...
# 2022-03-24  43.820000  43.820000
# 2022-03-25  44.400002  44.400002
# 2022-03-28  44.209999  44.209999
# 2022-03-29  43.720001  43.720001
# 2022-03-30  43.730000  43.730000
#
# [2540 rows x 2 columns]

# %%
indicadores = prices.join(conta['VL_CONTA'], how='outer')

# %%
indicadores.rename({'VL_CONTA':'LPA'}, axis=1, inplace = True)

# %%
indicadores.fillna(method='ffill', inplace=True)
indicadores.dropna(inplace=True)

# %%
# Comparing the close price and adjusted close price from yahoo finance api
indicadores['PL'] = indicadores['Close']/indicadores['LPA']
indicadores['PL_Ajustado'] = indicadores['Adj Close']/indicadores['LPA']
indicadores
# Out:
#             Adj Close      Close      LPA         PL  PL_Ajustado
# 2012-01-02   4.719447  12.400000  1.88010   6.595394     2.510211
# 2012-01-03   4.782880  12.566666  1.88010   6.684041     2.543950
# 2012-01-04   4.782880  12.566666  1.88010   6.684041     2.543950
# 2012-01-05   4.782880  12.566666  1.88010   6.684041     2.543950
# 2012-01-06   4.782880  12.566666  1.88010   6.684041     2.543950
# ...               ...        ...      ...        ...          ...
# 2022-03-24  43.820000  43.820000  2.14196  20.457898    20.457898
# 2022-03-25  44.400002  44.400002  2.14196  20.728679    20.728679
# 2022-03-28  44.209999  44.209999  2.14196  20.639974    20.639974
# 2022-03-29  43.720001  43.720001  2.14196  20.411213    20.411213
# 2022-03-30  43.730000  43.730000  2.14196  20.415881    20.415881
#
# [2550 rows x 5 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=indicadores.index, y=indicadores['PL'], name = 'PL'))
fig.add_trace(go.Scatter(x=indicadores.index, y=indicadores['PL_Ajustado'], name = 'PL_Ajustado'))
fig.add_trace(go.Scatter(x=indicadores.index, y=indicadores['Close'], name = 'TAEE11'))
fig.add_trace(go.Scatter(x=indicadores.index, y=indicadores['Adj Close'], name = 'TAEE11_Ajustado'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="85432e88-85c9-4591-9bd6-dd950faeb5cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85432e88-85c9-4591-9bd6-dd950faeb5cc")) {                    Plotly.newPlot(                        "85432e88-85c9-4591-9bd6-dd950faeb5cc",                        [{"name":"PL","x":["2012-01-02T00:00:00","2012-01-03T00:00:00","2012-01-04T00:00:00","2012-01-05T00:00:00","2012-01-06T00:00:00","2012-01-09T00:00:00","2012-01-10T00:00:00","2012-01-11T00:00:00","2012-01-12T00:00:00","2012-01-13T00:00:00","2012-01-16T00:00:00","2012-01-17T00:00:00","2012-01-18T00:00:00","2012-01-19T00:00:00","2012-01-20T00:00:00","2012-01-23T00:00:00","2012-01-24T00:00:00","2012-01-26T00:00:00","2012-01-27T00:00:00","2012-01-30T00:00:00","2012-01-31T00:00:00","2012-02-01T00:00:00","2012-02-02T00:00:00","2012-02-03T00:00:00","2012-02-06T00:00:00","2012-02-07T00:00:00","2012-02-08T00:00:00","2012-02-09T00:00:00","2012-02-10T00:00:00","2012-02-13T00:00:00","2012-02-14T00:00:00","2012-02-15T00:00:00","2012-02-16T00:00:00","2012-02-17T00:00:00","2012-02-23T00:00:00","2012-02-24T00:00:00","2012-02-27T00:00:00","2012-02-28T00:00:00","2012-02-29T00:00:00","2012-03-01T00:00:00","2012-03-02T00:00:00","2012-03-05T00:00:00","2012-03-06T00:00:00","2012-03-07T00:00:00","2012-03-08T00:00:00","2012-03-09T00:00:00","2012-03-12T00:00:00","2012-03-13T00:00:00","2012-03-14T00:00:00","2012-03-15T00:00:00","2012-03-16T00:00:00","2012-03-19T00:00:00","2012-03-20T00:00:00","2012-03-21T00:00:00","2012-03-22T00:00:00","2012-03-23T00:00:00","2012-03-26T00:00:00","2012-03-27T00:00:00","2012-03-28T00:00:00","2012-03-29T00:00:00","2012-03-30T00:00:00","2012-04-02T00:00:00","2012-04-03T00:00:00","2012-04-04T00:00:00","2012-04-05T00:00:00","2012-04-09T00:00:00","2012-04-10T00:00:00","2012-04-11T00:00:00","2012-04-12T00:00:00","2012-04-13T00:00:00","2012-04-16T00:00:00","2012-04-17T00:00:00","2012-04-18T00:00:00","2012-04-19T00:00:00","2012-04-20T00:00:00","2012-04-23T00:00:00","2012-04-24T00:00:00","2012-04-25T00:00:00","2012-04-26T00:00:00","2012-04-27T00:00:00","2012-04-30T00:00:00","2012-05-02T00:00:00","2012-05-03T00:00:00","2012-05-04T00:00:00","2012-05-07T00:00:00","2012-05-08T00:00:00","2012-05-09T00:00:00","2012-05-10T00:00:00","2012-05-11T00:00:00","2012-05-14T00:00:00","2012-05-15T00:00:00","2012-05-16T00:00:00","2012-05-17T00:00:00","2012-05-18T00:00:00","2012-05-21T00:00:00","2012-05-22T00:00:00","2012-05-23T00:00:00","2012-05-24T00:00:00","2012-05-25T00:00:00","2012-05-28T00:00:00","2012-05-29T00:00:00","2012-05-30T00:00:00","2012-05-31T00:00:00","2012-06-01T00:00:00","2012-06-04T00:00:00","2012-06-05T00:00:00","2012-06-06T00:00:00","2012-06-08T00:00:00","2012-06-11T00:00:00","2012-06-12T00:00:00","2012-06-13T00:00:00","2012-06-14T00:00:00","2012-06-15T00:00:00","2012-06-18T00:00:00","2012-06-19T00:00:00","2012-06-20T00:00:00","2012-06-21T00:00:00","2012-06-22T00:00:00","2012-06-25T00:00:00","2012-06-26T00:00:00","2012-06-27T00:00:00","2012-06-28T00:00:00","2012-06-29T00:00:00","2012-07-02T00:00:00","2012-07-03T00:00:00","2012-07-04T00:00:00","2012-07-05T00:00:00","2012-07-06T00:00:00","2012-07-10T00:00:00","2012-07-11T00:00:00","2012-07-12T00:00:00","2012-07-13T00:00:00","2012-07-16T00:00:00","2012-07-17T00:00:00","2012-07-18T00:00:00","2012-07-19T00:00:00","2012-07-20T00:00:00","2012-07-23T00:00:00","2012-07-24T00:00:00","2012-07-25T00:00:00","2012-07-26T00:00:00","2012-07-27T00:00:00","2012-07-30T00:00:00","2012-07-31T00:00:00","2012-08-01T00:00:00","2012-08-02T00:00:00","2012-08-03T00:00:00","2012-08-06T00:00:00","2012-08-07T00:00:00","2012-08-08T00:00:00","2012-08-09T00:00:00","2012-08-10T00:00:00","2012-08-13T00:00:00","2012-08-14T00:00:00","2012-08-15T00:00:00","2012-08-16T00:00:00","20 ...

# %% [markdown]
# ## Results

# %% [markdown]
# The graph shows this abrupt jumps and falls because of high LPA paid compared to previous period.
